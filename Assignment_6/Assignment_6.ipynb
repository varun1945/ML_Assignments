# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DATA=pd.read_csv("weather.csv")
DATA=DATA.dropna()
DATA.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
DATA.tail()
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
sns.distplot(DATA["Evaporation"])
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(DATA["MaxTemp"])
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(DATA["Sunshine"],shade=True)

# %%
sns.kdeplot(DATA["Evaporation"],shade=True)

# %%
sns.countplot(DATA['RainToday'])

# %%
sns.boxplot(DATA["Sunshine"])

# %%
with sns.axes_style('white'):
    sns.jointplot(x = DATA['MaxTemp'], y = DATA['MinTemp'], kind = 'hex', color = 'k')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x=DATA["MinTemp"], y=DATA["MaxTemp"])
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Cloud9am', y='Humidity9am', data=DATA, kind='kde')

# %%
DATA1=pd.DataFrame(DATA, columns=['Humidity3pm','Humidity9am','MinTemp','MaxTemp','RainToday'])
sns.pairplot(DATA1,hue='RainToday')

# %%
sns.stripplot(x ='Cloud3pm' , y='Humidity3pm', data=DATA)

# %%
sns.stripplot(x ='Cloud3pm' , y='Humidity3pm', data=DATA,jitter=True)

# %%
sns.swarmplot(x ='Cloud3pm' , y='Humidity3pm', data=DATA)

# %%
sns.boxplot(x='RainToday', y='Humidity9am', data=DATA, hue='WindDir3pm', dodge=True)

# %%
sns.boxplot(x='RainToday', y='Humidity9am', data=DATA, hue='WindDir3pm', dodge=False)

# %%
sns.countplot(x='WindDir9am', data=DATA, palette='Blues_d')

# %%
sns.countplot(x='Pressure9am', data=DATA, palette='Blues_d')
